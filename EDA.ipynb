# %% [markdown]
# # Mô tả dữ liệu

# %%
#import library
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Thế giới di động

# %%
tgdd=pd.read_csv("raw_data/thegioididong.csv")
tgdd.head()
# Out:
#    Unnamed: 0                                          Name  \
# 0           0  Điện thoại Samsung Galaxy S22 Ultra 5G 128GB
# 1           1                     Điện thoại iPhone 11 64GB
# 2           2                    Điện thoại OPPO Reno7 Z 5G
# 3           3                    Điện thoại Realme C35 64GB
# 4           4                Điện thoại Xiaomi 11T 5G 128GB
#
#               Screen          OS                             Rear camera  \
# 0  Dynamic AMOLED 2X  Android 12  Chính 108 MP & Phụ 12 MP, 10 MP, 10 MP
# 1            IPS LCD      iOS 15                          2 camera 12 MP
# 2             AMOLED  Android 11            Chính 64 MP & Phụ 2 MP, 2 MP
# 3            IPS LCD  Android 11          Chính 50 MP & Phụ 2 MP, 0.3 MP
# 4             AMOLED  Android 11           Chính 108 MP & Phụ 8 MP, 5 MP
#
#   Front camera                       Chip   RAM     ROM  \
# 0        40 MP  Snapdragon 8 Gen 1 8 nhân  8 GB  128 GB
# ...

# %%
tgdd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    96 non-null     int64
#  1   Name          96 non-null     object
#  2   Screen        96 non-null     object
#  3   OS            96 non-null     object
#  4   Rear camera   96 non-null     object
#  5   Front camera  96 non-null     object
#  6   Chip          96 non-null     object
#  7   RAM           96 non-null     object
#  8   ROM           96 non-null     object
#  9   SIM           94 non-null     object
#  10  Batery        91 non-null     object
#  11  Price         87 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 9.1+ KB

# %% [markdown]
# ## CellphoneS

# %%
cellphoneS=pd.read_csv("raw_data/cellphoneS.csv")
cellphoneS.head()
# Out:
#    Unnamed: 0                                       Name  Screen size  \
# 0           0                    Samsung Galaxy A73 (5G)   6.7 inches
# 1           1           iPhone 11 64GB I Chính hãng VN/A   6.1 inches
# 2           2  iPhone 13 Pro Max 128GB | Chính hãng VN/A   6.7 inches
# 3           3                       Xiaomi Redmi Note 11  6.43 inches
# 4           4  iPhone 12 Pro Max 128GB I Chính hãng VN/A   6.7 inches
#
#     Screen type                                        Rear camera  \
# 0  Super AMOLED  Camera chính: 108 MP, f/1.8, PDAF, OIS  Camera...
# 1       IPS LCD  Camera kép 12MP:- Camera góc rộng: ƒ/1.8 apert...
# 2          OLED  Camera góc rộng: 12MP, ƒ/1.5  Camera góc siêu ...
# 3        AMOLED  Camera góc rộng: 50 MP, f/1.8, PDAF  Camera gó...
# 4          OLED  Camera chính: 12 MP, f/1.6, 26mm, 1.4µm, dual ...
#
#                                         Front camera  \
# 0                                       32 MP, f/2.2
# ...

# %%
cellphoneS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         267 non-null    int64
#  1   Name               267 non-null    object
#  2   Screen size        265 non-null    object
#  3   Screen type        216 non-null    object
#  4   Rear camera        264 non-null    object
#  5   Front camera       263 non-null    object
#  6   Chip               265 non-null    object
#  7   RAM                255 non-null    object
#  8   ROM                267 non-null    object
#  9   Batery             266 non-null    object
#  10  SIM                260 non-null    object
#  11  OS                 260 non-null    object
#  12  Screen resolution  250 non-null    object
#  13  Screen feature     188 non-null    object
#  14  CPU type           222 non-null    object
#  15  Weight             245 non-null    object
# ...

# %% [markdown]
# ## Hoàng Hà mobile

# %%
hoangHa = [pd.read_csv('raw_data/hoangHa1.csv'),
                  pd.read_csv('raw_data/hoangHa2.csv')]
# ghép 2 file csv với nhau
hoangHa = pd.concat(hoangHa, ignore_index=True)
hoangHa.head()
# Out:
#    Unnamed: 0                                               Name  \
# 0           0                    Samsung Galaxy A73 - Chính hãng
# 1           1  Điện thoại di động Xiaomi Redmi Note 10 Pro 8G...
# 2           2  Samsung Galaxy Z Flip3 5G Flex Your Way (Phiên...
# 3           3  Điện thoại di động Samsung Galaxy S22 - 8GB/12...
# 4           4  Điện thoại di động Samsung Galaxy S22 - 8GB/25...
#
#                                   Screen type              Screen resolution  \
# 0                           Super AMOLED Plus  Full HD+ (1080 x 2400 Pixels)
# 1                                      AMOLED  Full HD+ (1080 x 2400 Pixels)
# 2                           Dynamic AMOLED 2X  Full HD+ (1080 x 2640 Pixels)
# 3  Dynamic AMOLED 2X, 10 - 120 Hz, Infinity O                    2340 x 1080
# 4  Dynamic AMOLED 2X, 10 - 120 Hz, Infinity O                    2340 x 1080
#
#                  Screen size                                       Camera  \
# ...

# %%
hoangHa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1259 non-null   int64
#  1   Name               1259 non-null   object
#  2   Screen type        1211 non-null   object
#  3   Screen resolution  1091 non-null   object
#  4   Screen size        610 non-null    object
#  5   Camera             1083 non-null   object
#  6   OS                 1019 non-null   object
#  7   Chip               1003 non-null   object
#  8   ROM                1091 non-null   object
#  9   RAM                1115 non-null   object
#  10  Mobile network     946 non-null    object
#  11  SIM                1003 non-null   object
#  12  Batery             979 non-null    object
#  13  Price              1259 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 137.8+ KB

# %% [markdown]
# ## Nguyễn Kim

# %%
nguyenKim=pd.read_csv("raw_data/nguyenkim.csv")
nguyenKim.head()
# Out:
#    Unnamed: 0                                 Name       Screen type  \
# 0           0    Điện thoại iPhone 12 64GB Xanh lá  Super Retina XDR
# 1           1        Điện thoại iPhone 12 128GB Đỏ  Super Retina XDR
# 2           2   Điện thoại iPhone 12 Pro 256GB Xám               NaN
# 3           3  Điện thoại iPhone 12 Pro 256GB Xanh               NaN
# 4           4   Điện thoại iPhone 13 Pro 128GB Bạc              OLED
#
#   Screen size   Screen resolution Front camera          Rear camera        OS  \
# 0  6.1 inch "  2532 x 1170 pixels         12MP          12 MP (kép)  iOS 14.1
# 1  6.1 inch "  2532 x 1170 pixels        12 MP          12 MP (kép)  iOS 14.1
# 2       6.1 "                 NaN        12 MP  12 MP, 12 MP, 12 MP  iOS 14.1
# 3       6.1 "                 NaN        12 MP  12 MP, 12 MP, 12 MP  iOS 14.1
# 4       6.1 "  2532 x 1170 pixels         12MP       12MP-12MP-12MP    iOS 15
#
#                Chip     ROM   RAM Batery        Price
# ...

# %%
nguyenKim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         209 non-null    int64
#  1   Name               209 non-null    object
#  2   Screen type        176 non-null    object
#  3   Screen size        207 non-null    object
#  4   Screen resolution  143 non-null    object
#  5   Front camera       206 non-null    object
#  6   Rear camera        202 non-null    object
#  7   OS                 152 non-null    object
#  8   Chip               193 non-null    object
#  9   ROM                209 non-null    object
#  10  RAM                206 non-null    object
#  11  Batery             120 non-null    object
#  12  Price              209 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 21.4+ KB

# %% [markdown]
# ## Ghép các bảng với nhau

# %%
raw_data_files = [pd.read_csv('raw_data/cellphoneS.csv'),
                  pd.read_csv('raw_data/hoangHa1.csv'),
                  pd.read_csv('raw_data/hoangHa2.csv'),
                  pd.read_csv('raw_data/nguyenkim.csv'),
                  pd.read_csv('raw_data/thegioididong.csv')]

data = pd.concat(raw_data_files, ignore_index=True)
data.head()
# Out:
#    Unnamed: 0                                       Name  Screen size  \
# 0           0                    Samsung Galaxy A73 (5G)   6.7 inches
# 1           1           iPhone 11 64GB I Chính hãng VN/A   6.1 inches
# 2           2  iPhone 13 Pro Max 128GB | Chính hãng VN/A   6.7 inches
# 3           3                       Xiaomi Redmi Note 11  6.43 inches
# 4           4  iPhone 12 Pro Max 128GB I Chính hãng VN/A   6.7 inches
#
#     Screen type                                        Rear camera  \
# 0  Super AMOLED  Camera chính: 108 MP, f/1.8, PDAF, OIS  Camera...
# 1       IPS LCD  Camera kép 12MP:- Camera góc rộng: ƒ/1.8 apert...
# 2          OLED  Camera góc rộng: 12MP, ƒ/1.5  Camera góc siêu ...
# 3        AMOLED  Camera góc rộng: 50 MP, f/1.8, PDAF  Camera gó...
# 4          OLED  Camera chính: 12 MP, f/1.6, 26mm, 1.4µm, dual ...
#
#                                         Front camera  \
# 0                                       32 MP, f/2.2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1831 entries, 0 to 1830
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1831 non-null   int64
#  1   Name               1831 non-null   object
#  2   Screen size        1082 non-null   object
#  3   Screen type        1603 non-null   object
#  4   Rear camera        562 non-null    object
#  5   Front camera       565 non-null    object
#  6   Chip               1557 non-null   object
#  7   RAM                1672 non-null   object
#  8   ROM                1663 non-null   object
#  9   Batery             1456 non-null   object
#  10  SIM                1357 non-null   object
#  11  OS                 1527 non-null   object
#  12  Screen resolution  1484 non-null   object
#  13  Screen feature     188 non-null    object
#  14  CPU type           222 non-null    object
#  15  Weight             245 non-null    object
# ...

# %%
import missingno as msno

msno.bar(data);

# %% [markdown]
# Chuyển đổi cột **Price** thành kiểu số

# %%
def filter_price(string):
    string = str(string)
    string = string.strip()

    string = string.replace('.', '')
    string = string.replace(',', '')
    string = string.replace('000\xa0₫', '')
    string = string.replace('000₫', '')
    string = string.replace('000đ', '')
    string = string.replace('000 ₫', '')
    string = string.replace('000 *', '')
    string = string.replace(' *', '')
    # nếu nan thì cho là 0
    if string == 'nan':
        return 0
    return int(string)

data['Price'] = data['Price'].apply(filter_price)

# %% [markdown]
# Biểu đồ phân bố của cột **Price**

# %%
plt.hist(data["Price"],bins=20);
fig = plt.figure(figsize =(10, 4))
plt.xlabel('Price (K₫)');
plt.ylabel('Quantity');
plt.title("Price histogram")
plt.show()

# %% [markdown]
# Biểu đồ hộp của cột **Price**

# %%
fig = plt.figure(figsize =(10, 7))
plt.boxplot(data["Price"])
plt.show()

# %% [markdown]
# Hầu hết các điện thoại đều dưới 50 triệu đồng, tuy nhiên có một số điện thoại lại lên đến 150 triệu thậm chí 400 triệu.

# %%
HighPriceMobile=data[data["Price"]>50000]
HighPriceMobile
# Out:
#       Unnamed: 0                                               Name  \
# 351           84  Điện thoại di động XOR Titanium X1 Classic - C...
# 352           85  Điện thoại di động XOR TITANIUM X1 CLASSIC ROS...
# 353           86  Điện thoại di động XOR TITANIUM X1 CLASSIC MAR...
# 354           87  Điện thoại di động XOR TITANIUM X1 EBONY - Chí...
# 355           88  Điện thoại di động XOR TITANIUM X1 CLASSIC BLA...
# ...          ...                                                ...
# 1475         860  Điện thoại di động  XOR TITANIUM X2 CLASSIC MA...
# 1476         861  Điện thoại di động XOR TITANIUM X2 EBONY BUNDL...
# 1477         862  Điện thoại di động XOR TITANIUM X2 CLASSIC BLA...
# 1478         863  Điện thoại di động  XOR TITANIUM X2 CLASSIC MA...
# 1479         864  Điện thoại di động XOR TITANIUM X2 CLASSIC ROS...
#
#      Screen size              Screen type Rear camera Front camera Chip  RAM  \
# ...

# %% [markdown]
# Hầu hết điện thoại trên 50 triệu là điện thoại Vertu có giá trị không phụ thuộc vào thông số kỹ thuật mà dựa vào thương hiệu và chất liệu là chủ yếu. Nên trong phần làm sạch dữ liệu sẽ xóa các điện thoại đó ra tập dữ liệu.
